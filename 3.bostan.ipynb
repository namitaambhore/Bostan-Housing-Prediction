# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
data=pd.read_csv('Boston Dataset (1).csv')

# %%
data
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %%
data
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
data.drop('rad',axis=1)
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  tax  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900  296
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671  242
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671  242
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622  222
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622  222
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786  273
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875  273
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675  273
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889  273
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050  273
#
#      ptratio   black  lstat  medv
# ...

# %%
data=data.drop('chas',axis=1)

# %%
data
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data['crim'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\136461904.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['crim'])

# %%
q=data['crim'].quantile(0.98)

# %%
q
# Out:
# 25.021659999999994

# %%
data1=data[data['crim']<q]

# %%
data1
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data1['crim'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\4007024671.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1['crim'])

# %%
sns.distplot(data['zn'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\836151443.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['zn'])

# %%
q=data['zn'].quantile(0.99)

# %%
q
# Out:
# 90.0

# %%
data2=data1[data1['zn']<q]

# %%
data2
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data2['zn'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\2157554394.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2['zn'])

# %%
sns.distplot(data['indus'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\2922767951.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['indus'])

# %%
q=data2['indus'].quantile(0.99)

# %%
q
# Out:
# 25.984399999999933

# %%
data3=data2[data2['indus']<q]

# %%
data3
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data3['indus'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\2199693893.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data3['indus'])

# %%
sns.distplot(data['nox'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\1344066683.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['nox'])

# %%
q=data['nox'].quantile(0.99)

# %%
q
# Out:
# 0.871

# %%
data4=data3[data3['nox']<q]

# %%
data4
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data4['nox'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\2049641034.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data4['nox'])

# %%
data
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data['rm'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\856639752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['rm'])

# %%
q=data['rm'].quantile(0.99)

# %%
q
# Out:
# 8.334999999999999

# %%
data5=data4[data4['rm']<q]

# %%
data5
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data['rm'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\856639752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['rm'])

# %%
q=data['rm'].quantile(0.01)

# %%
q
# Out:
# 4.52445

# %%
data6=data5[data5['rm']>q]

# %%
data6
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data6['rm'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\2818901756.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data6['rm'])

# %%
data
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data['age'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\3668578308.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['age'])

# %%
q=data['age'].quantile(0.70)

# %%
q
# Out:
# 91.8

# %%
data7=data6[data6['age']<q]

# %%
data7
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data7['age'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\3162565713.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data7['age'])

# %%
sns.distplot(data['age'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\3668578308.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['age'])

# %%
q=data['age'].quantile(0.01)

# %%
q
# Out:
# 6.609999999999999

# %%
data8=data7[data7['age']>q]

# %%
data8
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data8['age'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\3127196454.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data8['age'])

# %%
sns.distplot(data['dis'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\2062671797.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['dis'])

# %%
q=data['dis'].quantile(0.99)

# %%
q
# Out:
# 9.222769999999999

# %%
data9=data8[data8['dis']<q]

# %%
data9
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data9['dis'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\3536981071.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data9['dis'])

# %%
sns.distplot(data['tax'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\1487656357.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['tax'])

# %%
sns.distplot(data['ptratio'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\4219147454.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['ptratio'])

# %%
q=data['ptratio'].quantile(0.99)

# %%
data10=data9[data9['ptratio']<q]

# %%
data10
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data10['ptratio'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\3583040480.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data10['ptratio'])

# %%
sns.distplot(data['black'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\1349795278.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['black'])

# %%
q=data['black'].quantile(0.10)

# %%
q
# Out:
# 290.27

# %%
data11=data10[data10['black']>q]

# %%
data11
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data11['black'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\3337621836.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data11['black'])

# %%
sns.distplot(data['lstat'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\1359994569.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['lstat'])

# %%
q=data['lstat'].quantile(0.99)

# %%
q
# Out:
# 33.91849999999998

# %%
data12=data11[data11['lstat']<q]

# %%
data12
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data12['lstat'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\2318160656.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data12['lstat'])

# %%
sns.distplot(data['medv'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\3492536665.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['medv'])

# %%
q=data['medv'].quantile(0.99)

# %%
q
# Out:
# 50.0

# %%
data13=data12[data12['medv']<q]

# %%
data13
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
sns.distplot(data13['medv'])
plt.show()
# Out:
# C:\Users\Namita\AppData\Local\Temp\ipykernel_8772\2736431581.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data13['medv'])

# %%
data13
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 501         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 502         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 503         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 504         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 505         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
data13=data13.reset_index(drop=True)

# %%
data13
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 289         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 290         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 291         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 292         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 293         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
plt.scatter(data13['crim'],data13['medv'])
plt.show()

# %%
plt.scatter(data13['zn'],data13['medv'])
plt.show()

# %%
plt.scatter(data13['indus'],data13['medv'])
plt.show()

# %%
plt.scatter(data13['nox'],data13['medv'])
plt.show()

# %%
plt.scatter(data13['rm'],data13['medv'])
plt.show()

# %%
plt.scatter(data13['age'],data13['medv'])
plt.show()

# %%
plt.scatter(data13['dis'],data13['medv'])
plt.show()

# %%
plt.scatter(data13['rad'],data13['medv'])
plt.show()

# %%
plt.scatter(data13['tax'],data13['medv'])
plt.show()

# %%
plt.scatter(data13['ptratio'],data13['medv'])
plt.show()

# %%
plt.scatter(data13['black'],data13['medv'])
plt.show()

# %%
plt.scatter(data13['lstat'],data['medv'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 plt.scatter(data13['lstat'],data['medv'])
#       2 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3699, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3680 @_copy_docstring_and_deprecators(Axes.scatter)
#    3681 def scatter(
#    3682     x: float | ArrayLike,
#    (...)
#    3697     **kwargs,
#    3698 ) -> PathCollection:
# -> 3699     __ret = gca().scatter(
#    3700         x,
#    3701         y,
#    3702         s=s,
#    3703         c=c,
#    3704         marker=marker,
#    3705         cmap=cmap,
#    3706         norm=norm,
#    3707         vmin=vmin,
#    3708         vmax=vmax,
#    3709         alpha=alpha,
#    3710         linewidths=linewidths,
# ...

# %%
plt.scatter(data13['lstat'],data13['medv'])
plt.show()

# %%
log_medv=np.log(data13['medv'])

# %%
data13['medv']
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 289    22.4
# 290    20.6
# 291    23.9
# 292    22.0
# 293    11.9
# Name: medv, Length: 294, dtype: float64

# %%
log_medv
# Out:
# 0      3.178054
# 1      3.072693
# 2      3.546740
# 3      3.508556
# 4      3.589059
#          ...
# 289    3.109061
# 290    3.025291
# 291    3.173878
# 292    3.091042
# 293    2.476538
# Name: medv, Length: 294, dtype: float64

# %%
plt.scatter(data13['lstat'],log_medv)
plt.show()

# %%
data13=data13.drop('medv',axis=1)

# %%
data13
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 289         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 290         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 291         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 292         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 293         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat
# ...

# %%
data13['log_medv']=log_medv

# %%
data13
# Out:
#      Unnamed: 0     crim    zn  indus    nox     rm   age     dis  rad  tax  \
# 0             1  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296
# 1             2  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242
# 2             3  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242
# 3             4  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222
# 4             5  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222
# ..          ...      ...   ...    ...    ...    ...   ...     ...  ...  ...
# 289         502  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273
# 290         503  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273
# 291         504  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273
# 292         505  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273
# 293         506  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  log_medv
# ...

# %%
X=data13.drop('log_medv',axis=1)

# %%
y=data13['log_medv']

# %%
from sklearn.preprocessing import StandardScaler

# %%
model=StandardScaler()

# %%
X_std=model.fit_transform(X)

# %%
X_std
# Out:
# array([[-1.65457226, -0.3557281 ,  0.14976711, ..., -1.5365241 ,
#          0.57944296, -1.05132075],
#        [-1.64741372, -0.34721377, -0.6182247 , ..., -0.21286586,
#          0.57944296, -0.13737182],
#        [-1.64025518, -0.34722189, -0.6182247 , ..., -0.21286586,
#          0.3084126 , -1.26003505],
#        ...,
#        [ 1.94617318, -0.33364521, -0.6182247 , ...,  1.4814167 ,
#          0.57944296, -0.90631924],
#        [ 1.95333172, -0.31383794, -0.6182247 , ...,  1.4814167 ,
#          0.34969978, -0.72177186],
#        [ 1.96049026, -0.33906046, -0.6182247 , ...,  1.4814167 ,
#          0.57944296, -0.41419289]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_std,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.8008602851376101

# %%
y_pread1=model.predict(X_test)

# %%
y_pread1
# Out:
# array([3.1357689 , 3.14686512, 3.07137002, 3.07525382, 3.08633409,
#        3.37318783, 2.9962305 , 3.32083049, 3.14444694, 3.64339567,
#        2.89521097, 2.95205123, 2.97266112, 3.37744378, 3.52834229,
#        3.08000354, 2.96318903, 3.50929628, 3.2397379 , 3.23752512,
#        3.12587915, 3.03723199, 3.67512798, 3.0143637 , 2.91722681,
#        2.74215095, 3.60562067, 2.97835912, 3.15011587, 3.05619558,
#        3.42845581, 3.02765961, 2.99629609, 3.49317997, 3.18771814,
#        2.97395167, 2.9658944 , 2.89839887, 2.98936413, 3.23522704,
#        3.38397873, 3.10811607, 2.91264899, 3.16731549, 3.75891312,
#        3.71335827, 3.18870206, 3.16733519, 3.13033904, 2.98474426,
#        3.41164486, 3.25753702, 3.08361699, 3.0229939 , 3.04817761,
#        2.86942992, 2.959663  , 3.45418381, 3.02554844])

# %%
plt.scatter(y_test,y_pread1)
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model=DecisionTreeRegressor(max_depth=40,max_leaf_nodes=80)

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=40, max_leaf_nodes=80)

# %%
model.score(X_test,y_test)
# Out:
# 0.755926686662775

# %%
y_pread2=model.predict(X_test)

# %%
plt.scatter(y_test,y_pread2)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor(n_estimators=80)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=80)

# %%
model.score(X_test,y_test)
# Out:
# 0.7993865058608962

# %%
y_pread3=model.predict(X_test)

# %%
plt.scatter(y_test,y_pread3)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
model=GradientBoostingRegressor(n_estimators=80)

# %%
model.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(n_estimators=80)

# %%
model.score(X_test,y_test)
# Out:
# 0.8154008244009219

# %%
y_pread4=model.predict(X_test)

# %%
plt.scatter(y_test,y_pread4)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model=KNeighborsRegressor(n_neighbors=6)

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=6)

# %%
model.score(X_test,y_test)
# Out:
# 0.7228530871367541

# %%
y_pread5=model.predict(X_test)

# %%
plt.scatter(y_test,y_pread5)
plt.show()

# %%
from sklearn.svm import SVR

# %%
from sklearn.model_selection import GridSearchCV

# %%
hypermeters={'C':[1.2,1.5,2.2,3.5,3.2,4.1],'kernel':['linear', 'poly', 'rbf', 'sigmoid'],'degree':[1,2,4,8,10],'gamma':['scale','auto']}

# %%
model=GridSearchCV(SVR(),hypermeters,n_jobs=-1,verbose=4,cv=3)

# %%
model.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 240 candidates, totalling 720 fits
# GridSearchCV(cv=3, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1.2, 1.5, 2.2, 3.5, 3.2, 4.1],
#                          'degree': [1, 2, 4, 8, 10], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              verbose=4)

# %%
model.score(X_test,y_test)
# Out:
# 0.8121596178110261

# %%
model.best_params_
# Out:
# {'C': 1.2, 'degree': 1, 'gamma': 'auto', 'kernel': 'poly'}

# %%
y_pread6=model.predict(X_test)

# %%
plt.scatter(y_test,y_pread6)
plt.show()
